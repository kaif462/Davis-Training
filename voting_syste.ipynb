# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/voting_syste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
votes = ["A","B","A","C","A"]
unique = set()
count = {}

for v in votes:
    if v not in unique:
        unique.add(v)
        count[v] = votes.count(v)

winner = max(count, key=count.get)
print("Winner:", winner)
