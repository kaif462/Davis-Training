# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/filewriting_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filev=open("firstfile.txt","w")
print("Enter any five sentences:")
for x in range (5):
    sentence=input()
    filev.write(sentence)
    print ("data successfully written")
filev.close()
