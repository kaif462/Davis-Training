# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/filewriting3_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filev=open("firstfile.txt","r")
if(filev):
    data=filev.read()
    print (data)
    print("--_------")
    print("No of characters",len(data))
    filev.close()
else:
    print("Unable to open file")
