# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/Smart_student_result_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    with open("students.txt") as f:
        for line in f:
            try:
                id, name, m1, m2, m3 = line.strip().split(",")
                total = int(m1)+int(m2)+int(m3)
                percent = total/3

                if percent >= 90: grade = "A"
                elif percent >= 75: grade = "B"
                else: grade = "C"

                print(name, total, percent, grade)
            except:
                print("Invalid data:", line)
except FileNotFoundError:
    print("File not found")
