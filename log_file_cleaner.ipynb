# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/log_file_cleaner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("log.txt") as f:
    lines = f.readlines()

unique = set(lines)
error_count = 0

for line in unique:
    if "ERROR" in line:
        print(line.strip())
        error_count += 1

print("Total ERROR:", error_count)
