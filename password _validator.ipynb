# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/password%20_validator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class PasswordError(Exception): pass

pwd = input("Enter password: ")

if len(pwd) < 8:
    raise PasswordError("Too short")

if not any(c.isupper() for c in pwd):
    raise PasswordError("No uppercase")

if not any(c.islower() for c in pwd):
    raise PasswordError("No lowercase")

if not any(c.isdigit() for c in pwd):
    raise PasswordError("No digit")

print("Valid Password"))
