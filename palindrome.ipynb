# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif462/Davis-Training/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
words = input().lower()

for w in words:
    if w == w[::-1]:
        print(w)
